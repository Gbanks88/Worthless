# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %% [markdown]
# # Discrete-Time Signal Operations

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# A discrete-time signal $x[n]$ is shown below:
#
# <img src="dt_signal_ops_fig.png" width="350"/>
#
# Create an array for the following signal values from $n = -2,\dots,6$ for the shifted signal $\tilde{x}[n]$. E.g., to represent the figure above, we would use `x = np.array([0,1,1,1,1,1,0.5,0,0])`.

# %% [markdown]
# 1. $\tilde{x}[n]=x[n − 2]$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original signal x[n] for n = -2 to 6
x = np.array([0, 1, 1, 1, 1, 1, 0.5, 0, 0]).astype(float)

# Define the range of n for the shifted signal
n_vals = np.arange(-2, 7)

# Create the shifted signal \tilde{x}[n] = x[n - 2]
x_tilde = np.array([x[n - 2] if (n - 2) >= -2 and (n - 2) <= 6 else 0 for n in n_vals])

# Check the length of x_tilde
assert len(x_tilde) == 9

# Plot the original and shifted signals
plt.figure()
plt.stem(n_vals, x, label="$x[n]$")
plt.stem(n_vals, x_tilde, markerfmt="rx", linefmt="r-", label="$\\tilde{x}[n] = x[n - 2]$")
plt.legend()
plt.xlabel("$n$")
plt.ylabel("$x[n]$")
plt.title("Original and Shifted Signals")
plt.grid(True)
plt.show()

# %%
assert len(x_tilde) == 9
n_vals = np.arange(-2, 7)
x = np.array([0, 1, 1, 1, 1, 1, 0.5, 0, 0]).astype(float)

plt.figure()
plt.stem(n_vals, x, label="$x[n]$")
plt.stem(n_vals, x_tilde, markerfmt="rx", linefmt="r-", label="$\\widetilde{x}[n]$")
plt.legend()
plt.xlabel("$n$")
# Out:
# Text(0.5, 0, '$n$')

# %% [markdown]
# 2. $\tilde{x}[n]=x[4-n]$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original signal x[n]
x = np.array([0, 1, 1, 1, 1, 1, 0.5, 0, 0]).astype(float)

# Range of n
n_vals = np.arange(-2, 7)

# Shifted signal \tilde{x}[n] = x[n - 2]
x_tilde_1 = np.array([x[n - 2] if (n - 2) >= -2 and (n - 2) <= 6 else 0 for n in n_vals])

# Check length
assert len(x_tilde_1) == 9

# Plot
plt.figure()
plt.stem(n_vals, x, label="$x[n]$")
plt.stem(n_vals, x_tilde_1, markerfmt="rx", linefmt="r-", label="$\\tilde{x}[n] = x[n - 2]$")
plt.legend()
plt.xlabel("$n$")
plt.ylabel("$x[n]$")
plt.title("Original and Shifted Signals")
plt.grid(True)
plt.show()

# %%
assert len(x_tilde) == 9

plt.figure()
plt.stem(n_vals, x, label="$x[n]$")
plt.stem(n_vals, x_tilde, markerfmt="rx", linefmt="r-", label="$\\widetilde{x}[n]$")
plt.xlabel("$n$")
plt.legend()

# %% [markdown]
# 3. $\tilde{x}[n]=x[2n]$

# %%
# Scaled signal \tilde{x}[n] = x[2n]
x_tilde_2 = np.array([x[2 * n] if (2 * n) >= -2 and (2 * n) <= 6 else 0 for n in n_vals])

# Check length
assert len(x_tilde_2) == 9

# Plot
plt.figure()
plt.stem(n_vals, x, label="$x[n]$")
plt.stem(n_vals, x_tilde_2, markerfmt="rx", linefmt="r-", label="$\\tilde{x}[n] = x[2n]$")
plt.legend()
plt.xlabel("$n$")
plt.ylabel("$x[n]$")
plt.title("Original and Scaled Signals")
plt.grid(True)
plt.show()

# %%
assert len(x_tilde) == 9

plt.figure()
plt.stem(n_vals, x, label="$x[n]$")
plt.stem(n_vals, x_tilde, markerfmt="rx", linefmt="r-", label="$\\widetilde{x}[n]$")
plt.xlabel("$n$")
plt.legend()

# %% [markdown]
# 4. $\tilde{x}[n]=x[n]u[2-n]$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original signal x[n]
x = np.array([0, 1, 1, 1, 1, 1, 0.5, 0, 0]).astype(float)

# Range of n
n_vals = np.arange(-2, 7)

# Shifted signal \tilde{x}[n] = x[n - 2]
x_tilde_1 = np.array([x[n - 2] if (n - 2) >= -2 and (n - 2) <= 6 else 0 for n in n_vals])

# Check length
assert len(x_tilde_1) == 9

# Plot
plt.figure()
plt.stem(n_vals, x, label="$x[n]$")
plt.stem(n_vals, x_tilde_1, markerfmt="rx", linefmt="r-", label="$\\tilde{x}[n] = x[n - 2]$")
plt.legend()
plt.xlabel("$n$")
plt.ylabel("$x[n]$")
plt.title("Original and Shifted Signals")
plt.grid(True)
plt.show()

# %%
assert len(x_tilde) == 9

plt.figure()
plt.stem(n_vals, x, label="$x[n]$")
plt.stem(n_vals, x_tilde, markerfmt="rx", linefmt="r-", label="$\\widetilde{x}[n]$")
plt.xlabel("$n$")
plt.legend()

# %% [markdown]
# 5. $\tilde{x}[n]=x[n-1]\delta [n-3]$

# %%
# Dirac delta function δ[n-3]
delta = np.array([1 if n == 3 else 0 for n in n_vals])

# Signal \tilde{x}[n] = x[n-1]\delta[n-3]
x_tilde_3 = np.array([x[n-1] if (n-1) >= -2 and (n-1) <= 6 else 0 for n in n_vals]) * delta

# Check length
assert len(x_tilde_3) == 9

# Plot
plt.figure()
plt.stem(n_vals, x, label="$x[n]$")
plt.stem(n_vals, x_tilde_3, markerfmt="rx", linefmt="r-", label="$\\tilde{x}[n] = x[n-1]\delta[n-3]$")
plt.legend()
plt.xlabel("$n$")
plt.ylabel("$x[n]$")
plt.title("Original and Delta-Multiplied Signals")
plt.grid(True)
plt.show()

# %%
assert len(x_tilde) == 9

plt.figure()
plt.stem(n_vals, x, label="$x[n]$")
plt.stem(n_vals, x_tilde, markerfmt="rx", linefmt="r-", label="$\\widetilde{x}[n]$")
plt.xlabel("$n$")
plt.legend()
